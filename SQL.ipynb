# %% [markdown]
# <a href="https://colab.research.google.com/github/Sambhaji6529/SQL_Practice/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SQL Query :-**

# %% [markdown]
# # **Q.1**
# ![Screenshot (5).png](data:image/png;base64,...)

# %%
select first_name,last_name,gender from patients where gender='M'

# %% [markdown]
# # **Q.2**
# ![Screenshot (6).png](data:image/png;base64,...)

# %%
select first_name,last_name from patients where  allergies is null;

# %% [markdown]
# # **Q.3**
# ![Screenshot (7).png](data:image/png;base64,...)

# %%
select first_name from patients where first_name like'c%';

# %% [markdown]
# # **Q.4**
#
# ![Screenshot (8).png](data:image/png;base64,...)

# %%
select first_name,last_name from patients where weight between 100 and 120;

# %% [markdown]
# # **Q.5**
#
# ![Screenshot (9).png](data:image/png;base64,...)

# %%
update  patients set allergies = 'NKA' where allergies is null;

# %% [markdown]
# # **Q.6**
# ![Screenshot (10).png](data:image/png;base64,...)

# %%
select  concat(first_name, " ",last_name) as full_name from patients;
