# %% [markdown]
# <a href="https://colab.research.google.com/github/Sambhaji6529/SQL_Practice/blob/main/SQL_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot (60).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (61).png](data:image/png;base64,...)
