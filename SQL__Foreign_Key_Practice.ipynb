# %% [markdown]
# <a href="https://colab.research.google.com/github/Sambhaji6529/SQL_Practice/blob/main/SQL__Foreign_Key_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Foreign Key**
#
#
# *   Check Constraints
# *   Default Constraints

# %%
   create table person2(
   id int Not Null,
   first_name varchar(25) Not Null,
   last_name varchar(28) Not Null,
   age int,
   salary int,
   primary key(id)
   );

# %% [markdown]
# ![Screenshot (49).png](data:image/png;base64,...)

# %%
create table department(
id int Not Null,
department_id int  Not Null,
department_name varchar(25) Not Null,
primary key(department_id)
);

desc department;

# %% [markdown]
# ![Screenshot (50).png](data:image/png;base64,...)

# %%
#After Add foreign key 
alter table department
add foreign key(id) references person2(id);

# %%
 #check constraints
   create table person2(
   id int Not Null,
   first_name varchar(25) Not Null,
   last_name varchar(28) Not Null,
   age int,
   salary int,
   primary key(id),
   check(salary<50000)
   );
   desc person2;

# %% [markdown]
# ![Screenshot (49).png](data:image/png;base64,...)

# %%
insert into person2 values(1,'sambhaji','sonwane',21,40000);
   
select * from person2;

# %% [markdown]
# ![Screenshot (51).png](data:image/png;base64,...)

# %%
   #Default constraint
   drop table person2;
   
   create table person2(
   id int Not Null,
   first_name varchar(25) Not Null,
   last_name varchar(28) Not Null,
   city_name varchar(29) default 'Pune'
   );

# %%
  desc person2;

# %% [markdown]
# ![Screenshot (52).png](data:image/png;base64,...)

# %%
   #delete default value
   alter table person2
   alter city_name drop default;

# %% [markdown]
# ![Screenshot (53).png](data:image/png;base64,...)
